# %% [markdown]
# Exploring the double well
# ------

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import keras
import tensorflow as tf
import sys
# Out:
# Using TensorFlow backend.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
rcParams.update({'font.size': 16})

# %%
# Switch AUTORELOAD ON. Disable this when in production mode!
# %load_ext autoreload
# %autoreload 2

# %%
from deep_boltzmann.models import DoubleWell
from deep_boltzmann.networks.invertible import EnergyInvNet, invnet
from deep_boltzmann.sampling import GaussianPriorMCMC
from deep_boltzmann.networks.plot import test_xz_projection
from deep_boltzmann.util import count_transitions
from deep_boltzmann.sampling.analysis import free_energy_bootstrap, mean_finite, std_finite

# %%
def test_sample(network, temperature=1.0):
    sample_z, sample_x, energy_z, energy_x, logw = network.sample(temperature=temperature, nsample=100000)
    # xgen = network.Tzx.predict(np.sqrt(temperature) * np.random.randn(100000, 2))
    params = DoubleWell.params_default.copy()
    params['dim'] = 2
    double_well = DoubleWell(params=params)
    plt.figure(figsize=(5, 4))
    _, E = double_well.plot_dimer_energy(temperature=temperature)
    h, b = np.histogram(sample_x[:, 0], bins=100)
    Eh = -np.log(h) / temperature
    Eh = Eh - Eh.min() + E.min()
    bin_means = 0.5*(b[:-1] + b[1:])
    plt.plot(bin_means, Eh)
    return bin_means, Eh

# %%
# reweighting
def test_sample_rew(network, temperature=1.0):
    sample_z, sample_x, energy_z, energy_x, log_w = network.sample(temperature=1.0, nsample=100000)
    bin_means, Es = free_energy_bootstrap(sample_x[:, 0], -2.5, 2.5, 100, sample=100, weights=np.exp(log_w))
    plt.figure(figsize=(5, 4))
    double_well.plot_dimer_energy()
    Emean = mean_finite(Es, axis=0)-10.7
    Estd = std_finite(Es, axis=0)
    plt.errorbar(bin_means, Emean, Estd)
    # variance
    var = mean_finite(std_finite(Es, axis=0) ** 2)
    print('Estimator Standard Error: ', np.sqrt(var))
    return bin_means, Emean, Estd

# %%
def plot_transformation_field_2d(transformer, bounds, ngrid=20, ):
    # build grid
    x_coarse_grid = np.linspace(bounds[0], bounds[1], num=ngrid)
    y_coarse_grid = np.linspace(bounds[2], bounds[3], num=ngrid)
    grid = []
    for i in range(len(x_coarse_grid)):
        for j in range(len(y_coarse_grid)):
            grid.append([x_coarse_grid[i], y_coarse_grid[j]])
    grid = np.array(grid)

    # compute transformation field
    grid_pred = transformer.predict(grid)

    # show field
    plt.figure(figsize=(5, 5))
    plt.quiver(grid[:, 0], grid[:, 1], grid_pred[:, 0], grid_pred[:, 1], units='width')

# %%
def getx(x):
    return x[:, 0]

# %%
def plot_convergence(losses, acceptance_rate, stepsize=None, figsize=(5, 8)):
    fig, axes = plt.subplots(nrows=3, ncols=1, sharex=True, figsize=figsize)
    niter = len(losses)
    xticks = np.arange(niter) + 1
    # ML loss
    losses_ML = np.array(losses)[:, 1]
    axes[0].plot(xticks, losses_ML, color='black')
    axes[0].set_xlim(0, niter + 1)
    axes[0].set_ylabel('ML loss')
    # KL loss
    losses_KL = np.array(losses)[:, 2]
    axes[1].plot(xticks, losses_KL, color='black')
    axes[1].set_xlim(0, niter + 1)
    axes[1].set_ylabel('KL loss')
    if stepsize is None:
        # acceptance rate
        axes[2].plot(xticks, acceptance_rate, color='black')
        axes[2].set_xlim(0, niter + 1)
        axes[2].set_ylabel('Acc. rate')
        axes[2].set_xlabel('Training iterations')
    else:
        # MCMC efficiency (adaptive)
        efficiency = np.array(acceptance_rate) * np.array(stepsize)
        axes[2].plot(xticks, efficiency, color='black')
        axes[2].set_xlim(0, niter + 1)
        axes[2].set_ylabel('Efficiency')
        axes[2].set_xlabel('Training iterations')
    return fig, axes

# %%
paper_dir = '/Users/noe/data/papers/NoeEtAl_BoltzmannGeneratorsRev/'

# %% [markdown]
# Double well
# ---

# %%
params = DoubleWell.params_default.copy()
params['dim'] = 2
double_well = DoubleWell(params=params)
plt.figure(figsize=(5,5))
double_well.plot_dimer_energy();
#plt.savefig(paper_dir + 'figs/doublewell_potential.pdf', bbox_inches='tight')

# %%
def plot_potential(labels=True, cbar=True, figsize=(5, 5)):
    # 2D potential
    xgrid = np.linspace(-3, 3, 100)
    ygrid = np.linspace(-6, 6, 100)
    Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
    X = np.vstack([Xgrid.flatten(), Ygrid.flatten()]).T
    E = double_well.energy(X)
    E = E.reshape((100, 100))
    E = np.minimum(E, 10.0)
    plt.figure(figsize=figsize)
    plt.contourf(Xgrid, Ygrid, E, 50, cmap='jet', vmax=4)
    if cbar:
        cbar = plt.colorbar()
        cbar.set_label('Energy / kT', labelpad=-15, y=0.6)
        cbar.set_ticks([-10, -5, 0, 5, 10])
    if labels:
        plt.xlabel('$x_1$ / a.u.')
        plt.ylabel('$x_2$ / a.u.')
    else:
        plt.xticks([])
        plt.yticks([])

# %%
print(params)
# Out:
# {'k': 1.0, 'dim': 2, 'a4': 1.0, 'a2': 6.0, 'a1': 1.0}

# %%
# simulation data
from deep_boltzmann.sampling import MetropolisGauss

# %%
nsteps = 10000
x0_left = np.array([[-1.8, 0.0]])
x0_right = np.array([[1.8, 0.0]])

sampler = MetropolisGauss(double_well, x0_left, noise=0.1, stride=10)
sampler.run(nsteps)
traj_left = sampler.traj.copy()

sampler.reset(x0_left)
sampler.run(nsteps)
traj_left_val = sampler.traj.copy()

sampler.reset(x0_right)
sampler.run(nsteps)
traj_right = sampler.traj.copy()

sampler.reset(x0_right)
sampler.run(nsteps)
traj_right_val = sampler.traj.copy()

# %%
plt.figure(figsize=(10, 4))
ax1 = plt.subplot2grid((1, 3), (0, 0), colspan=2)
ax2 = plt.subplot2grid((1, 3), (0, 2))
ax1.plot(traj_left[:, 0], color='blue', alpha=0.7)
ax1.plot(traj_right[:, 0], color='red', alpha=0.7)
ax1.set_xlim(0, 1000)
ax1.set_ylim(-2.5, 2.5)
ax1.set_xlabel('Time / steps')
ax1.set_ylabel('x / a.u.')
ax2.hist(traj_left[:, 0], 30, orientation='horizontal', histtype='stepfilled', color='blue', alpha=0.2);
ax2.hist(traj_left[:, 0], 30, orientation='horizontal', histtype='step', color='blue', linewidth=2);
ax2.hist(traj_right[:, 0], 30, orientation='horizontal', histtype='stepfilled', color='red', alpha=0.2);
ax2.hist(traj_right[:, 0], 30, orientation='horizontal', histtype='step', color='red', linewidth=2);
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_ylim(-2.5, 2.5)
ax2.set_xlabel('Probability')
#plt.savefig(paper_dir + 'figs/doublewell_prior_trajs.pdf', bbox_inches='tight')
# Out:
# Text(0.5,0,'Probability')

# %%
x = np.vstack([traj_left, traj_right])
xval = np.vstack([traj_left_val, traj_right_val])

# %%
# prepare transition state
x_ts = np.vstack([np.zeros(1000), (1.0/double_well.params['k']) * np.random.randn(1000)]).T

# %% [markdown]
# Particle filter starting from one sample
# -----

# %%
bg = invnet(double_well.dim, 'RRRR', double_well, nl_layers=3, nl_hidden=100, 
            nl_activation='relu', nl_activation_scale='tanh')
# Out:
# <RRRR>
# < 2 0 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# > 1 1 0
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
x0 = traj_left[100:101]
X0 = np.repeat(x0, 1000, axis=0)
X0 += 0.01 * np.random.randn(X0.shape[0], X0.shape[1])

# %%
plot_potential(labels=False, cbar=False, figsize=(5, 5))
plt.plot(x0[:, 0], x0[:, 1], color='white', linewidth=0, marker='+', markersize=20, markeredgewidth=3)
#plt.savefig(paper_dir + 'figs/double_well/explore_potential_init.pdf', bbox_inches='tight', transparent=True)

# %%
loss_bg_trainML, loss_bg_valML = bg.train_ML(X0, epochs=20, batch_size=128, 
                                             std=1.0, verbose=0, return_test_energies=False)
# Out:
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
plt.plot(loss_bg_trainML)
plt.plot(loss_bg_valML)

# %%
from deep_boltzmann.networks.training import ParticleFilter

# %%
particle_filter = ParticleFilter(bg, X0, 10000, lr=0.00025, batch_size=1024, 
                                 high_energy=10000, max_energy=1e10, std=1.0)

# %%
Ds = []
Ds.append(particle_filter.X[:, 0].copy())

# %%
for i in range(10):
    print('\nITER',(i+1),'/10')
    particle_filter.train(epochs=50, stepsize=None, verbose=1)
    Ds.append(particle_filter.X[:, 0].copy())
# Out:
# ITER 1 /10
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 0/50 loss 2.3956 index_layer_3_loss -2.6828 index_layer_6_loss 5.0784 p_acc 0.896484375 step 0.1
# Epoch 1/50 loss 8.5126 index_layer_3_loss -2.5342 index_layer_6_loss 11.0468 p_acc 0.9013671875 step 0.1
# Epoch 2/50 loss 1.2440 index_layer_3_loss -2.6794 index_layer_6_loss 3.9234 p_acc 0.8955078125 step 0.1
# Epoch 3/50 loss -0.9248 index_layer_3_loss -2.7503 index_layer_6_loss 1.8254 p_acc 0.896484375 step 0.1
# Epoch 4/50 loss -2.2952 index_layer_3_loss -2.7034 index_layer_6_loss 0.4081 p_acc 0.888671875 step 0.1
# Epoch 5/50 loss -2.3167 index_layer_3_loss -2.6804 index_layer_6_loss 0.3637 p_acc 0.88671875 step 0.1
# Epoch 6/50 loss -2.6029 index_layer_3_loss -2.7195 index_layer_6_loss 0.1166 p_acc 0.90234375 step 0.1
# Epoch 7/50 loss -3.4350 index_layer_3_loss -2.7567 index_layer_6_loss -0.6783 p_acc 0.8974609375 step 0.1
# Epoch 8/50 loss -3.5535 index_layer_3_loss -2.7357 index_layer_6_loss -0.8179 p_acc 0.9169921875 step 0.1
# Epoch 9/50 loss -3.3573 index_layer_3_loss -2.7052 index_layer_6_loss -0.6522 p_acc 0.908203125 step 0.1
# Epoch 10/50 loss -3.5058 index_layer_3_loss -2.7126 index_layer_6_loss -0.7932 p_acc 0.892578125 step 0.1
# Epoch 11/50 loss -4.5861 index_layer_3_loss -2.7291 index_layer_6_loss -1.8571 p_acc 0.9033203125 step 0.1
# Epoch 12/50 loss -3.4338 index_layer_3_loss -2.6978 index_layer_6_loss -0.7361 p_acc 0.89453125 step 0.1
# Epoch 13/50 loss -3.4730 index_layer_3_loss -2.6662 index_layer_6_loss -0.8068 p_acc 0.87890625 step 0.1
# Epoch 14/50 loss -4.6543 index_layer_3_loss -2.6515 index_layer_6_loss -2.0028 p_acc 0.921875 step 0.1
# Epoch 15/50 loss -4.2891 index_layer_3_loss -2.6702 index_layer_6_loss -1.6189 p_acc 0.91015625 step 0.1
# Epoch 16/50 loss -4.5786 index_layer_3_loss -2.6825 index_layer_6_loss -1.8962 p_acc 0.921875 step 0.1
# Epoch 17/50 loss -5.2121 index_layer_3_loss -2.6632 index_layer_6_loss -2.5489 p_acc 0.904296875 step 0.1
# Epoch 18/50 loss -5.2150 index_layer_3_loss -2.6502 index_layer_6_loss -2.5648 p_acc 0.916015625 step 0.1
# Epoch 19/50 loss -4.7033 index_layer_3_loss -2.6519 index_layer_6_loss -2.0514 p_acc 0.9208984375 step 0.1
# Epoch 20/50 loss 1.9547 index_layer_3_loss -2.6619 index_layer_6_loss 4.6166 p_acc 0.892578125 step 0.1
# Epoch 21/50 loss -5.0539 index_layer_3_loss -2.6557 index_layer_6_loss -2.3982 p_acc 0.89453125 step 0.1
# Epoch 22/50 loss -5.2932 index_layer_3_loss -2.6520 index_layer_6_loss -2.6412 p_acc 0.912109375 step 0.1
# Epoch 23/50 loss -4.8214 index_layer_3_loss -2.6605 index_layer_6_loss -2.1609 p_acc 0.8935546875 step 0.1
# Epoch 24/50 loss -4.8077 index_layer_3_loss -2.6738 index_layer_6_loss -2.1339 p_acc 0.9072265625 step 0.1
# Epoch 25/50 loss -5.1707 index_layer_3_loss -2.6716 index_layer_6_loss -2.4992 p_acc 0.921875 step 0.1
# Epoch 26/50 loss -5.0934 index_layer_3_loss -2.6806 index_layer_6_loss -2.4128 p_acc 0.90234375 step 0.1
# Epoch 27/50 loss -4.4152 index_layer_3_loss -2.6914 index_layer_6_loss -1.7238 p_acc 0.9140625 step 0.1
# Epoch 28/50 loss -5.3399 index_layer_3_loss -2.6960 index_layer_6_loss -2.6440 p_acc 0.908203125 step 0.1
# Epoch 29/50 loss -5.2380 index_layer_3_loss -2.6998 index_layer_6_loss -2.5382 p_acc 0.888671875 step 0.1
# Epoch 30/50 loss -4.8855 index_layer_3_loss -2.7091 index_layer_6_loss -2.1763 p_acc 0.8935546875 step 0.1
# Epoch 31/50 loss -5.1998 index_layer_3_loss -2.7125 index_layer_6_loss -2.4873 p_acc 0.90625 step 0.1
# Epoch 32/50 loss -4.8706 index_layer_3_loss -2.7174 index_layer_6_loss -2.1532 p_acc 0.90625 step 0.1
# Epoch 33/50 loss -5.1457 index_layer_3_loss -2.7305 index_layer_6_loss -2.4152 p_acc 0.9013671875 step 0.1
# Epoch 34/50 loss -4.9731 index_layer_3_loss -2.7357 index_layer_6_loss -2.2374 p_acc 0.921875 step 0.1
# Epoch 35/50 loss -5.3108 index_layer_3_loss -2.7452 index_layer_6_loss -2.5656 p_acc 0.9111328125 step 0.1
# Epoch 36/50 loss -5.1838 index_layer_3_loss -2.7502 index_layer_6_loss -2.4335 p_acc 0.904296875 step 0.1
# Epoch 37/50 loss -5.2268 index_layer_3_loss -2.7554 index_layer_6_loss -2.4714 p_acc 0.8916015625 step 0.1
# Epoch 38/50 loss -5.0283 index_layer_3_loss -2.7546 index_layer_6_loss -2.2737 p_acc 0.8798828125 step 0.1
# Epoch 39/50 loss -5.5861 index_layer_3_loss -2.7621 index_layer_6_loss -2.8240 p_acc 0.89453125 step 0.1
# Epoch 40/50 loss -5.2956 index_layer_3_loss -2.7670 index_layer_6_loss -2.5285 p_acc 0.890625 step 0.1
# Epoch 41/50 loss -5.9085 index_layer_3_loss -2.7705 index_layer_6_loss -3.1380 p_acc 0.9072265625 step 0.1
# Epoch 42/50 loss -5.3789 index_layer_3_loss -2.7740 index_layer_6_loss -2.6049 p_acc 0.896484375 step 0.1
# Epoch 43/50 loss -5.6877 index_layer_3_loss -2.7759 index_layer_6_loss -2.9119 p_acc 0.9091796875 step 0.1
# Epoch 44/50 loss -5.4045 index_layer_3_loss -2.7842 index_layer_6_loss -2.6202 p_acc 0.9169921875 step 0.1
# Epoch 45/50 loss -5.7470 index_layer_3_loss -2.7895 index_layer_6_loss -2.9575 p_acc 0.92578125 step 0.1
# Epoch 46/50 loss -5.8526 index_layer_3_loss -2.7975 index_layer_6_loss -3.0551 p_acc 0.900390625 step 0.1
# Epoch 47/50 loss -5.7393 index_layer_3_loss -2.7954 index_layer_6_loss -2.9440 p_acc 0.8935546875 step 0.1
# Epoch 48/50 loss -6.0467 index_layer_3_loss -2.8101 index_layer_6_loss -3.2366 p_acc 0.9052734375 step 0.1
# Epoch 49/50 loss -5.8114 index_layer_3_loss -2.8129 index_layer_6_loss -2.9985 p_acc 0.9248046875 step 0.1
#
# ITER 2 /10
# Epoch 0/50 loss -5.6968 index_layer_3_loss -2.8201 index_layer_6_loss -2.8768 p_acc 0.9111328125 step 0.10200000000000001
# Epoch 1/50 loss -6.0077 index_layer_3_loss -2.8236 index_layer_6_loss -3.1841 p_acc 0.900390625 step 0.10404000000000001
# Epoch 2/50 loss -6.2555 index_layer_3_loss -2.8309 index_layer_6_loss -3.4245 p_acc 0.9091796875 step 0.10612080000000002
# Epoch 3/50 loss -6.5026 index_layer_3_loss -2.8400 index_layer_6_loss -3.6626 p_acc 0.904296875 step 0.10824321600000002
# Epoch 4/50 loss -6.2507 index_layer_3_loss -2.8398 index_layer_6_loss -3.4109 p_acc 0.90625 step 0.11040808032000002
# Epoch 5/50 loss -6.3889 index_layer_3_loss -2.8515 index_layer_6_loss -3.5373 p_acc 0.8994140625 step 0.11261624192640002
# Epoch 6/50 loss -6.3049 index_layer_3_loss -2.8614 index_layer_6_loss -3.4434 p_acc 0.8994140625 step 0.11486856676492802
# Epoch 7/50 loss -6.2148 index_layer_3_loss -2.8613 index_layer_6_loss -3.3535 p_acc 0.8955078125 step 0.11716593810022657
# Epoch 8/50 loss -6.4903 index_layer_3_loss -2.8751 index_layer_6_loss -3.6152 p_acc 0.8828125 step 0.11950925686223111
# Epoch 9/50 loss -6.4003 index_layer_3_loss -2.8832 index_layer_6_loss -3.5170 p_acc 0.9033203125 step 0.12189944199947574
# Epoch 10/50 loss -5.5598 index_layer_3_loss -2.8844 index_layer_6_loss -2.6753 p_acc 0.8916015625 step 0.12433743083946525
# Epoch 11/50 loss -6.6981 index_layer_3_loss -2.8977 index_layer_6_loss -3.8005 p_acc 0.876953125 step 0.12682417945625454
# Epoch 12/50 loss -6.7776 index_layer_3_loss -2.8994 index_layer_6_loss -3.8781 p_acc 0.9033203125 step 0.12936066304537963
# Epoch 13/50 loss -6.7038 index_layer_3_loss -2.9084 index_layer_6_loss -3.7955 p_acc 0.8828125 step 0.13194787630628724
# Epoch 14/50 loss -6.7850 index_layer_3_loss -2.9193 index_layer_6_loss -3.8657 p_acc 0.890625 step 0.134586833832413
# Epoch 15/50 loss -6.7786 index_layer_3_loss -2.9262 index_layer_6_loss -3.8524 p_acc 0.9140625 step 0.13727857050906125
# Epoch 16/50 loss -6.9054 index_layer_3_loss -2.9323 index_layer_6_loss -3.9731 p_acc 0.9052734375 step 0.14002414191924248
# Epoch 17/50 loss -7.0835 index_layer_3_loss -2.9403 index_layer_6_loss -4.1432 p_acc 0.8994140625 step 0.14282462475762733
# Epoch 18/50 loss -7.1076 index_layer_3_loss -2.9591 index_layer_6_loss -4.1486 p_acc 0.8857421875 step 0.14568111725277988
# Epoch 19/50 loss -7.2474 index_layer_3_loss -2.9594 index_layer_6_loss -4.2880 p_acc 0.8984375 step 0.14859473959783548
# Epoch 20/50 loss -7.2399 index_layer_3_loss -2.9722 index_layer_6_loss -4.2677 p_acc 0.87890625 step 0.1515666343897922
# Epoch 21/50 loss -7.2600 index_layer_3_loss -2.9859 index_layer_6_loss -4.2741 p_acc 0.876953125 step 0.15459796707758805
# Epoch 22/50 loss -7.3769 index_layer_3_loss -2.9920 index_layer_6_loss -4.3848 p_acc 0.873046875 step 0.15768992641913981
# Epoch 23/50 loss -7.4159 index_layer_3_loss -3.0037 index_layer_6_loss -4.4122 p_acc 0.8818359375 step 0.1608437249475226
# Epoch 24/50 loss -7.5450 index_layer_3_loss -3.0103 index_layer_6_loss -4.5347 p_acc 0.880859375 step 0.16406059944647305
# Epoch 25/50 loss -7.6723 index_layer_3_loss -3.0193 index_layer_6_loss -4.6530 p_acc 0.859375 step 0.16734181143540253
# Epoch 26/50 loss -7.6527 index_layer_3_loss -3.0224 index_layer_6_loss -4.6303 p_acc 0.8798828125 step 0.17068864766411057
# Epoch 27/50 loss -7.7772 index_layer_3_loss -3.0487 index_layer_6_loss -4.7285 p_acc 0.875 step 0.17410242061739278
# Epoch 28/50 loss -7.4578 index_layer_3_loss -3.0470 index_layer_6_loss -4.4108 p_acc 0.8876953125 step 0.17758446902974065
# Epoch 29/50 loss -7.1859 index_layer_3_loss -3.0603 index_layer_6_loss -4.1257 p_acc 0.861328125 step 0.18113615841033545
# Epoch 30/50 loss -7.7273 index_layer_3_loss -3.0616 index_layer_6_loss -4.6657 p_acc 0.8515625 step 0.18475888157854217
# Epoch 31/50 loss -6.6934 index_layer_3_loss -3.0766 index_layer_6_loss -3.6168 p_acc 0.876953125 step 0.18845405921011302
# Epoch 32/50 loss -7.7584 index_layer_3_loss -3.0870 index_layer_6_loss -4.6714 p_acc 0.8642578125 step 0.1922231403943153
# Epoch 33/50 loss -7.4777 index_layer_3_loss -3.0907 index_layer_6_loss -4.3870 p_acc 0.8798828125 step 0.1960676032022016
# Epoch 34/50 loss -7.7377 index_layer_3_loss -3.1004 index_layer_6_loss -4.6374 p_acc 0.8623046875 step 0.19998895526624563
# Epoch 35/50 loss -7.9382 index_layer_3_loss -3.1009 index_layer_6_loss -4.8373 p_acc 0.857421875 step 0.20398873437157056
# Epoch 36/50 loss -7.7775 index_layer_3_loss -3.1042 index_layer_6_loss -4.6733 p_acc 0.857421875 step 0.20806850905900198
# Epoch 37/50 loss -7.8261 index_layer_3_loss -3.1279 index_layer_6_loss -4.6981 p_acc 0.8388671875 step 0.21222987924018202
# Epoch 38/50 loss -8.0457 index_layer_3_loss -3.1080 index_layer_6_loss -4.9377 p_acc 0.8623046875 step 0.21647447682498566
# Epoch 39/50 loss -8.0827 index_layer_3_loss -3.1243 index_layer_6_loss -4.9584 p_acc 0.8681640625 step 0.2208039663614854
# Epoch 40/50 loss -8.0600 index_layer_3_loss -3.1357 index_layer_6_loss -4.9243 p_acc 0.84765625 step 0.2252200456887151
# Epoch 41/50 loss -8.2005 index_layer_3_loss -3.1435 index_layer_6_loss -5.0570 p_acc 0.8662109375 step 0.2297244466024894
# Epoch 42/50 loss -8.3943 index_layer_3_loss -3.1000 index_layer_6_loss -5.2943 p_acc 0.857421875 step 0.23431893553453917
# Epoch 43/50 loss -8.0907 index_layer_3_loss -3.1590 index_layer_6_loss -4.9317 p_acc 0.8505859375 step 0.23900531424522994
# Epoch 44/50 loss -8.3601 index_layer_3_loss -3.1389 index_layer_6_loss -5.2212 p_acc 0.84375 step 0.24378542053013455
# Epoch 45/50 loss -8.4119 index_layer_3_loss -3.1339 index_layer_6_loss -5.2780 p_acc 0.83203125 step 0.24866112894073725
# Epoch 46/50 loss -8.3396 index_layer_3_loss -3.1591 index_layer_6_loss -5.1805 p_acc 0.865234375 step 0.253634351519552
# Epoch 47/50 loss -8.3237 index_layer_3_loss -3.1577 index_layer_6_loss -5.1661 p_acc 0.8447265625 step 0.25870703854994304
# Epoch 48/50 loss -8.4682 index_layer_3_loss -3.1547 index_layer_6_loss -5.3134 p_acc 0.8408203125 step 0.2638811793209419
# Epoch 49/50 loss -8.4384 index_layer_3_loss -3.1889 index_layer_6_loss -5.2495 p_acc 0.8427734375 step 0.2691588029073608
#
# ITER 3 /10
# Epoch 0/50 loss -8.5043 index_layer_3_loss -3.1868 index_layer_6_loss -5.3175 p_acc 0.85546875 step 0.27454197896550797
# Epoch 1/50 loss -8.5549 index_layer_3_loss -3.1934 index_layer_6_loss -5.3615 p_acc 0.8408203125 step 0.28003281854481815
# Epoch 2/50 loss -8.5532 index_layer_3_loss -3.1699 index_layer_6_loss -5.3833 p_acc 0.8369140625 step 0.2856334749157145
# Epoch 3/50 loss -8.3743 index_layer_3_loss -3.1619 index_layer_6_loss -5.2124 p_acc 0.82421875 step 0.2913461444140288
# Epoch 4/50 loss -8.5595 index_layer_3_loss -3.1902 index_layer_6_loss -5.3693 p_acc 0.8212890625 step 0.29717306730230936
# Epoch 5/50 loss -8.8069 index_layer_3_loss -3.1485 index_layer_6_loss -5.6584 p_acc 0.8017578125 step 0.30311652864835553
# Epoch 6/50 loss -8.4277 index_layer_3_loss -3.1997 index_layer_6_loss -5.2280 p_acc 0.837890625 step 0.30917885922132265
# Epoch 7/50 loss -8.7636 index_layer_3_loss -3.1677 index_layer_6_loss -5.5959 p_acc 0.8037109375 step 0.3153624364057491
# Epoch 8/50 loss -8.6487 index_layer_3_loss -3.1592 index_layer_6_loss -5.4894 p_acc 0.8115234375 step 0.3216696851338641
# Epoch 9/50 loss -8.3833 index_layer_3_loss -3.1284 index_layer_6_loss -5.2549 p_acc 0.8125 step 0.32810307883654144
# Epoch 10/50 loss -8.7356 index_layer_3_loss -3.1377 index_layer_6_loss -5.5979 p_acc 0.822265625 step 0.3346651404132723
# Epoch 11/50 loss -8.6520 index_layer_3_loss -3.0973 index_layer_6_loss -5.5547 p_acc 0.7998046875 step 0.34135844322153774
# Epoch 12/50 loss -8.6571 index_layer_3_loss -3.1516 index_layer_6_loss -5.5055 p_acc 0.783203125 step 0.3481856120859685
# Epoch 13/50 loss -8.8497 index_layer_3_loss -3.1314 index_layer_6_loss -5.7183 p_acc 0.7880859375 step 0.35514932432768787
# Epoch 14/50 loss -8.7588 index_layer_3_loss -3.0699 index_layer_6_loss -5.6889 p_acc 0.7841796875 step 0.36225231081424164
# Epoch 15/50 loss -8.3618 index_layer_3_loss -2.7514 index_layer_6_loss -5.6104 p_acc 0.794921875 step 0.3694973570305265
# Epoch 16/50 loss -8.9042 index_layer_3_loss -3.0782 index_layer_6_loss -5.8260 p_acc 0.8056640625 step 0.376887304171137
# Epoch 17/50 loss -8.7406 index_layer_3_loss -2.9477 index_layer_6_loss -5.7929 p_acc 0.76171875 step 0.38442505025455975
# Epoch 18/50 loss -8.8277 index_layer_3_loss -3.0085 index_layer_6_loss -5.8192 p_acc 0.7705078125 step 0.39211355125965097
# Epoch 19/50 loss -8.5199 index_layer_3_loss -2.8448 index_layer_6_loss -5.6750 p_acc 0.7236328125 step 0.399955822284844
# Epoch 20/50 loss -8.5293 index_layer_3_loss -2.8243 index_layer_6_loss -5.7051 p_acc 0.7470703125 step 0.4079549387305409
# Epoch 21/50 loss -8.4063 index_layer_3_loss -2.7676 index_layer_6_loss -5.6386 p_acc 0.7451171875 step 0.41611403750515175
# Epoch 22/50 loss -8.5177 index_layer_3_loss -2.7676 index_layer_6_loss -5.7501 p_acc 0.7548828125 step 0.4244363182552548
# Epoch 23/50 loss -8.1322 index_layer_3_loss -2.8939 index_layer_6_loss -5.2384 p_acc 0.7734375 step 0.4329250446203599
# Epoch 24/50 loss -7.2935 index_layer_3_loss -1.4077 index_layer_6_loss -5.8858 p_acc 0.7919921875 step 0.44158354551276713
# Epoch 25/50 loss -7.5324 index_layer_3_loss -1.7324 index_layer_6_loss -5.8000 p_acc 0.7373046875 step 0.45041521642302246
# Epoch 26/50 loss -7.0543 index_layer_3_loss -2.6954 index_layer_6_loss -4.3589 p_acc 0.6767578125 step 0.4594235207514829
# Epoch 27/50 loss -8.3797 index_layer_3_loss -2.6731 index_layer_6_loss -5.7065 p_acc 0.6591796875 step 0.4686119911665126
# Epoch 28/50 loss -7.6433 index_layer_3_loss -2.1541 index_layer_6_loss -5.4892 p_acc 0.6171875 step 0.47798423098984283
# Epoch 29/50 loss -7.4217 index_layer_3_loss -2.0464 index_layer_6_loss -5.3753 p_acc 0.59375 step 0.48754391560963967
# Epoch 30/50 loss -4.3670 index_layer_3_loss 0.3479 index_layer_6_loss -4.7149 p_acc 0.55859375 step 0.49729479392183246
# Epoch 31/50 loss -6.4348 index_layer_3_loss -1.5251 index_layer_6_loss -4.9097 p_acc 0.55859375 step 0.5072406898002692
# Epoch 32/50 loss -6.0618 index_layer_3_loss -1.2841 index_layer_6_loss -4.7777 p_acc 0.546875 step 0.5173855035962746
# Epoch 33/50 loss -6.1005 index_layer_3_loss -1.4779 index_layer_6_loss -4.6227 p_acc 0.5576171875 step 0.5277332136682
# Epoch 34/50 loss -5.7765 index_layer_3_loss -0.9382 index_layer_6_loss -4.8383 p_acc 0.5361328125 step 0.5382878779415641
# Epoch 35/50 loss -6.0750 index_layer_3_loss -0.9604 index_layer_6_loss -5.1146 p_acc 0.568359375 step 0.5490536355003953
# Epoch 36/50 loss -6.0794 index_layer_3_loss -0.9386 index_layer_6_loss -5.1408 p_acc 0.5732421875 step 0.5600347082104032
# Epoch 37/50 loss -6.4139 index_layer_3_loss -1.1570 index_layer_6_loss -5.2569 p_acc 0.5908203125 step 0.5712354023746113
# Epoch 38/50 loss -5.5338 index_layer_3_loss -0.1457 index_layer_6_loss -5.3881 p_acc 0.580078125 step 0.5826601104221035
# Epoch 39/50 loss -5.8832 index_layer_3_loss -0.0990 index_layer_6_loss -5.7842 p_acc 0.630859375 step 0.5943133126305457
# Epoch 40/50 loss -5.3914 index_layer_3_loss 0.4775 index_layer_6_loss -5.8689 p_acc 0.638671875 step 0.6061995788831566
# Epoch 41/50 loss -7.0088 index_layer_3_loss -0.9568 index_layer_6_loss -6.0520 p_acc 0.626953125 step 0.6183235704608198
# Epoch 42/50 loss -5.8088 index_layer_3_loss 0.0936 index_layer_6_loss -5.9024 p_acc 0.6484375 step 0.6306900418700362
# Epoch 43/50 loss -5.6078 index_layer_3_loss 0.4642 index_layer_6_loss -6.0720 p_acc 0.6357421875 step 0.6433038427074369
# Epoch 44/50 loss -7.2265 index_layer_3_loss -1.1996 index_layer_6_loss -6.0269 p_acc 0.63671875 step 0.6561699195615857
# Epoch 45/50 loss -6.1964 index_layer_3_loss -0.0371 index_layer_6_loss -6.1593 p_acc 0.6279296875 step 0.6692933179528174
# Epoch 46/50 loss -4.2239 index_layer_3_loss 1.9542 index_layer_6_loss -6.1781 p_acc 0.5869140625 step 0.6826791843118738
# Epoch 47/50 loss -1.2224 index_layer_3_loss 4.7989 index_layer_6_loss -6.0213 p_acc 0.5087890625 step 0.6963327679981113
# Epoch 48/50 loss -6.3385 index_layer_3_loss -0.5255 index_layer_6_loss -5.8131 p_acc 0.5068359375 step 0.7102594233580736
# Epoch 49/50 loss -4.5997 index_layer_3_loss 0.7470 index_layer_6_loss -5.3468 p_acc 0.458984375 step 0.724464611825235
#
# ITER 4 /10
# Epoch 0/50 loss -5.2998 index_layer_3_loss -0.2354 index_layer_6_loss -5.0644 p_acc 0.462890625 step 0.7389539040617398
# Epoch 1/50 loss -4.6279 index_layer_3_loss -0.3251 index_layer_6_loss -4.3028 p_acc 0.4052734375 step 0.7537329821429746
# Epoch 2/50 loss -3.3795 index_layer_3_loss 0.2093 index_layer_6_loss -3.5888 p_acc 0.412109375 step 0.768807641785834
# Epoch 3/50 loss -3.6868 index_layer_3_loss 0.0573 index_layer_6_loss -3.7441 p_acc 0.3818359375 step 0.7841837946215507
# Epoch 4/50 loss -3.0954 index_layer_3_loss 0.2388 index_layer_6_loss -3.3342 p_acc 0.3984375 step 0.7998674705139818
# Epoch 5/50 loss -2.9417 index_layer_3_loss 0.5785 index_layer_6_loss -3.5202 p_acc 0.3896484375 step 0.8158648199242614
# Epoch 6/50 loss -2.7839 index_layer_3_loss 0.7834 index_layer_6_loss -3.5674 p_acc 0.373046875 step 0.8321821163227466
# Epoch 7/50 loss -1.8365 index_layer_3_loss 1.4158 index_layer_6_loss -3.2524 p_acc 0.37109375 step 0.8488257586492016
# Epoch 8/50 loss -1.8002 index_layer_3_loss 1.6610 index_layer_6_loss -3.4612 p_acc 0.3828125 step 0.8658022738221857
# Epoch 9/50 loss -0.9795 index_layer_3_loss 2.7382 index_layer_6_loss -3.7177 p_acc 0.3564453125 step 0.8831183192986294
# Epoch 10/50 loss -2.7597 index_layer_3_loss 1.2959 index_layer_6_loss -4.0557 p_acc 0.3330078125 step 0.900780685684602
# Epoch 11/50 loss -3.1580 index_layer_3_loss 1.1527 index_layer_6_loss -4.3107 p_acc 0.37109375 step 0.9187962993982941
# Epoch 12/50 loss -3.5705 index_layer_3_loss 1.0206 index_layer_6_loss -4.5911 p_acc 0.3564453125 step 0.93717222538626
# Epoch 13/50 loss -2.4195 index_layer_3_loss 2.4075 index_layer_6_loss -4.8270 p_acc 0.330078125 step 0.9559156698939852
# Epoch 14/50 loss -3.6363 index_layer_3_loss 1.5025 index_layer_6_loss -5.1387 p_acc 0.3623046875 step 0.975033983291865
# Epoch 15/50 loss -3.6406 index_layer_3_loss 1.5952 index_layer_6_loss -5.2358 p_acc 0.3720703125 step 0.9945346629577023
# Epoch 16/50 loss -4.0247 index_layer_3_loss 1.3930 index_layer_6_loss -5.4178 p_acc 0.349609375 step 1.0
# Epoch 17/50 loss -4.0778 index_layer_3_loss 1.5296 index_layer_6_loss -5.6074 p_acc 0.314453125 step 1.0
# Epoch 18/50 loss -2.7962 index_layer_3_loss 1.5881 index_layer_6_loss -4.3843 p_acc 0.3349609375 step 1.0
# Epoch 19/50 loss -3.9942 index_layer_3_loss 1.6978 index_layer_6_loss -5.6921 p_acc 0.365234375 step 1.0
# Epoch 20/50 loss -3.7828 index_layer_3_loss 1.7287 index_layer_6_loss -5.5116 p_acc 0.3818359375 step 1.0
# Epoch 21/50 loss -3.8010 index_layer_3_loss 1.7894 index_layer_6_loss -5.5904 p_acc 0.3583984375 step 1.0
# Epoch 22/50 loss -3.0449 index_layer_3_loss 2.0046 index_layer_6_loss -5.0495 p_acc 0.38671875 step 1.0
# Epoch 23/50 loss -3.8899 index_layer_3_loss 1.9473 index_layer_6_loss -5.8372 p_acc 0.36328125 step 1.0
# Epoch 24/50 loss -3.5956 index_layer_3_loss 2.0624 index_layer_6_loss -5.6580 p_acc 0.3603515625 step 1.0
# Epoch 25/50 loss -4.0685 index_layer_3_loss 1.9295 index_layer_6_loss -5.9980 p_acc 0.3857421875 step 1.0
# Epoch 26/50 loss -3.7455 index_layer_3_loss 2.1851 index_layer_6_loss -5.9306 p_acc 0.3720703125 step 1.0
# Epoch 27/50 loss -3.7773 index_layer_3_loss 2.0107 index_layer_6_loss -5.7881 p_acc 0.3486328125 step 1.0
# Epoch 28/50 loss 2.0288 index_layer_3_loss 1.8883 index_layer_6_loss 0.1405 p_acc 0.390625 step 1.0
# Epoch 29/50 loss -3.8106 index_layer_3_loss 2.0402 index_layer_6_loss -5.8507 p_acc 0.392578125 step 1.0
# Epoch 30/50 loss -3.3071 index_layer_3_loss 1.9465 index_layer_6_loss -5.2536 p_acc 0.3759765625 step 1.0
# Epoch 31/50 loss -3.3057 index_layer_3_loss 2.5023 index_layer_6_loss -5.8080 p_acc 0.3779296875 step 1.0
# Epoch 32/50 loss -3.3865 index_layer_3_loss 2.6387 index_layer_6_loss -6.0252 p_acc 0.396484375 step 1.0
# Epoch 33/50 loss -2.7290 index_layer_3_loss 3.3161 index_layer_6_loss -6.0451 p_acc 0.369140625 step 1.0
# Epoch 34/50 loss -2.8270 index_layer_3_loss 2.9707 index_layer_6_loss -5.7977 p_acc 0.3544921875 step 1.0
# Epoch 35/50 loss -3.1048 index_layer_3_loss 2.8550 index_layer_6_loss -5.9598 p_acc 0.3447265625 step 1.0
# Epoch 36/50 loss -3.6521 index_layer_3_loss 2.4790 index_layer_6_loss -6.1311 p_acc 0.3583984375 step 1.0
# Epoch 37/50 loss -1.6483 index_layer_3_loss 3.1578 index_layer_6_loss -4.8062 p_acc 0.33984375 step 1.0
# Epoch 38/50 loss -2.4544 index_layer_3_loss 3.5356 index_layer_6_loss -5.9900 p_acc 0.33203125 step 1.0
# Epoch 39/50 loss -2.9633 index_layer_3_loss 2.8497 index_layer_6_loss -5.8131 p_acc 0.3681640625 step 1.0
# Epoch 40/50 loss -2.5960 index_layer_3_loss 3.0917 index_layer_6_loss -5.6878 p_acc 0.3447265625 step 1.0
# Epoch 41/50 loss -3.1988 index_layer_3_loss 2.5128 index_layer_6_loss -5.7116 p_acc 0.365234375 step 1.0
# Epoch 42/50 loss -2.7522 index_layer_3_loss 2.9011 index_layer_6_loss -5.6533 p_acc 0.412109375 step 1.0
# Epoch 43/50 loss -2.4214 index_layer_3_loss 3.2786 index_layer_6_loss -5.7000 p_acc 0.3505859375 step 1.0
# Epoch 44/50 loss -2.7027 index_layer_3_loss 2.5284 index_layer_6_loss -5.2310 p_acc 0.3564453125 step 1.0
# Epoch 45/50 loss -3.1506 index_layer_3_loss 2.7885 index_layer_6_loss -5.9391 p_acc 0.357421875 step 1.0
# Epoch 46/50 loss -2.6593 index_layer_3_loss 3.1681 index_layer_6_loss -5.8274 p_acc 0.3857421875 step 1.0
# Epoch 47/50 loss -3.2265 index_layer_3_loss 2.7295 index_layer_6_loss -5.9560 p_acc 0.35546875 step 1.0
# Epoch 48/50 loss -2.7773 index_layer_3_loss 2.9219 index_layer_6_loss -5.6992 p_acc 0.349609375 step 1.0
# Epoch 49/50 loss -3.1154 index_layer_3_loss 2.7912 index_layer_6_loss -5.9066 p_acc 0.3515625 step 1.0
#
# ITER 5 /10
# Epoch 0/50 loss -3.5998 index_layer_3_loss 2.3710 index_layer_6_loss -5.9709 p_acc 0.36328125 step 1.0
# Epoch 1/50 loss -2.1843 index_layer_3_loss 2.7904 index_layer_6_loss -4.9748 p_acc 0.37890625 step 1.0
# Epoch 2/50 loss -3.3236 index_layer_3_loss 2.5449 index_layer_6_loss -5.8685 p_acc 0.3583984375 step 1.0
# Epoch 3/50 loss -2.5257 index_layer_3_loss 2.6813 index_layer_6_loss -5.2070 p_acc 0.345703125 step 1.0
# Epoch 4/50 loss -3.7631 index_layer_3_loss 2.2440 index_layer_6_loss -6.0071 p_acc 0.3525390625 step 1.0
# Epoch 5/50 loss -3.5616 index_layer_3_loss 2.4758 index_layer_6_loss -6.0374 p_acc 0.3544921875 step 1.0
# Epoch 6/50 loss -3.6190 index_layer_3_loss 2.2536 index_layer_6_loss -5.8726 p_acc 0.3486328125 step 1.0
# Epoch 7/50 loss -2.9237 index_layer_3_loss 2.1534 index_layer_6_loss -5.0771 p_acc 0.3642578125 step 1.0
# Epoch 8/50 loss -3.3643 index_layer_3_loss 2.4637 index_layer_6_loss -5.8280 p_acc 0.3271484375 step 1.0
# Epoch 9/50 loss -3.1298 index_layer_3_loss 2.3672 index_layer_6_loss -5.4970 p_acc 0.326171875 step 1.0
# Epoch 10/50 loss -3.2894 index_layer_3_loss 2.3527 index_layer_6_loss -5.6421 p_acc 0.3671875 step 1.0
# Epoch 11/50 loss -3.2887 index_layer_3_loss 2.4644 index_layer_6_loss -5.7531 p_acc 0.376953125 step 1.0
# Epoch 12/50 loss -3.5542 index_layer_3_loss 2.1137 index_layer_6_loss -5.6679 p_acc 0.35546875 step 1.0
# Epoch 13/50 loss -3.1558 index_layer_3_loss 2.1302 index_layer_6_loss -5.2860 p_acc 0.33203125 step 1.0
# Epoch 14/50 loss -2.9445 index_layer_3_loss 1.9934 index_layer_6_loss -4.9379 p_acc 0.3603515625 step 1.0
# Epoch 15/50 loss -3.5783 index_layer_3_loss 2.1007 index_layer_6_loss -5.6791 p_acc 0.3427734375 step 1.0
# Epoch 16/50 loss -3.4776 index_layer_3_loss 2.3663 index_layer_6_loss -5.8439 p_acc 0.36328125 step 1.0
# Epoch 17/50 loss -3.4721 index_layer_3_loss 2.3500 index_layer_6_loss -5.8221 p_acc 0.3603515625 step 1.0
# Epoch 18/50 loss -3.1359 index_layer_3_loss 2.1555 index_layer_6_loss -5.2913 p_acc 0.333984375 step 1.0
# Epoch 19/50 loss -3.9725 index_layer_3_loss 2.0670 index_layer_6_loss -6.0395 p_acc 0.3662109375 step 1.0
# Epoch 20/50 loss -2.7044 index_layer_3_loss 2.0527 index_layer_6_loss -4.7570 p_acc 0.34375 step 1.0
# Epoch 21/50 loss -3.3779 index_layer_3_loss 2.3397 index_layer_6_loss -5.7175 p_acc 0.3662109375 step 1.0
# Epoch 22/50 loss -3.9498 index_layer_3_loss 2.1960 index_layer_6_loss -6.1459 p_acc 0.3603515625 step 1.0
# Epoch 23/50 loss -3.8272 index_layer_3_loss 2.1081 index_layer_6_loss -5.9354 p_acc 0.349609375 step 1.0
# Epoch 24/50 loss -3.5161 index_layer_3_loss 2.2752 index_layer_6_loss -5.7912 p_acc 0.349609375 step 1.0
# Epoch 25/50 loss -3.3934 index_layer_3_loss 2.3869 index_layer_6_loss -5.7803 p_acc 0.3515625 step 1.0
# Epoch 26/50 loss -3.8160 index_layer_3_loss 2.1276 index_layer_6_loss -5.9436 p_acc 0.3544921875 step 1.0
# Epoch 27/50 loss -3.1894 index_layer_3_loss 2.5773 index_layer_6_loss -5.7667 p_acc 0.3525390625 step 1.0
# Epoch 28/50 loss -3.8596 index_layer_3_loss 2.1869 index_layer_6_loss -6.0466 p_acc 0.3828125 step 1.0
# Epoch 29/50 loss -3.5227 index_layer_3_loss 2.3476 index_layer_6_loss -5.8703 p_acc 0.3544921875 step 1.0
# Epoch 30/50 loss -3.6140 index_layer_3_loss 2.4601 index_layer_6_loss -6.0741 p_acc 0.365234375 step 1.0
# Epoch 31/50 loss -3.9415 index_layer_3_loss 2.1806 index_layer_6_loss -6.1221 p_acc 0.3662109375 step 1.0
# Epoch 32/50 loss -3.6102 index_layer_3_loss 2.0154 index_layer_6_loss -5.6256 p_acc 0.3720703125 step 1.0
# Epoch 33/50 loss -3.8249 index_layer_3_loss 2.1014 index_layer_6_loss -5.9263 p_acc 0.3662109375 step 1.0
# Epoch 34/50 loss -3.7742 index_layer_3_loss 2.2214 index_layer_6_loss -5.9956 p_acc 0.3564453125 step 1.0
# Epoch 35/50 loss -3.4501 index_layer_3_loss 2.1115 index_layer_6_loss -5.5617 p_acc 0.349609375 step 1.0
# Epoch 36/50 loss -3.9444 index_layer_3_loss 2.1817 index_layer_6_loss -6.1261 p_acc 0.3525390625 step 1.0
# Epoch 37/50 loss -3.9021 index_layer_3_loss 2.1518 index_layer_6_loss -6.0539 p_acc 0.3701171875 step 1.0
# Epoch 38/50 loss -3.4004 index_layer_3_loss 2.3804 index_layer_6_loss -5.7808 p_acc 0.365234375 step 1.0
# Epoch 39/50 loss -3.6273 index_layer_3_loss 1.9719 index_layer_6_loss -5.5992 p_acc 0.373046875 step 1.0
# Epoch 40/50 loss -3.7378 index_layer_3_loss 2.1146 index_layer_6_loss -5.8524 p_acc 0.34765625 step 1.0
# Epoch 41/50 loss -3.9298 index_layer_3_loss 2.2192 index_layer_6_loss -6.1490 p_acc 0.3798828125 step 1.0
# Epoch 42/50 loss -3.4120 index_layer_3_loss 2.1486 index_layer_6_loss -5.5606 p_acc 0.3994140625 step 1.0
# Epoch 43/50 loss -3.7261 index_layer_3_loss 2.2658 index_layer_6_loss -5.9919 p_acc 0.3720703125 step 1.0
# Epoch 44/50 loss -3.5523 index_layer_3_loss 2.1066 index_layer_6_loss -5.6589 p_acc 0.3623046875 step 1.0
# Epoch 45/50 loss -4.1614 index_layer_3_loss 2.0657 index_layer_6_loss -6.2271 p_acc 0.3779296875 step 1.0
# Epoch 46/50 loss -3.6309 index_layer_3_loss 2.1679 index_layer_6_loss -5.7988 p_acc 0.3564453125 step 1.0
# Epoch 47/50 loss -4.1279 index_layer_3_loss 2.1179 index_layer_6_loss -6.2458 p_acc 0.3662109375 step 1.0
# Epoch 48/50 loss -3.8072 index_layer_3_loss 2.4220 index_layer_6_loss -6.2292 p_acc 0.3779296875 step 1.0
# Epoch 49/50 loss -2.7150 index_layer_3_loss 2.3003 index_layer_6_loss -5.0153 p_acc 0.3623046875 step 1.0
#
# ITER 6 /10
# Epoch 0/50 loss -4.0629 index_layer_3_loss 2.2749 index_layer_6_loss -6.3378 p_acc 0.3740234375 step 1.0
# Epoch 1/50 loss -4.1407 index_layer_3_loss 2.2618 index_layer_6_loss -6.4025 p_acc 0.37109375 step 1.0
# Epoch 2/50 loss -4.4575 index_layer_3_loss 1.7942 index_layer_6_loss -6.2517 p_acc 0.3740234375 step 1.0
# Epoch 3/50 loss -3.8752 index_layer_3_loss 2.3824 index_layer_6_loss -6.2576 p_acc 0.3505859375 step 1.0
# Epoch 4/50 loss -3.9255 index_layer_3_loss 2.2597 index_layer_6_loss -6.1852 p_acc 0.3720703125 step 1.0
# Epoch 5/50 loss -3.7388 index_layer_3_loss 2.1183 index_layer_6_loss -5.8571 p_acc 0.3681640625 step 1.0
# Epoch 6/50 loss -4.0066 index_layer_3_loss 2.1667 index_layer_6_loss -6.1733 p_acc 0.3525390625 step 1.0
# Epoch 7/50 loss -4.3286 index_layer_3_loss 2.0945 index_layer_6_loss -6.4231 p_acc 0.375 step 1.0
# Epoch 8/50 loss -4.0852 index_layer_3_loss 1.9845 index_layer_6_loss -6.0697 p_acc 0.361328125 step 1.0
# Epoch 9/50 loss -3.7620 index_layer_3_loss 2.2124 index_layer_6_loss -5.9744 p_acc 0.376953125 step 1.0
# Epoch 10/50 loss -4.0595 index_layer_3_loss 2.1362 index_layer_6_loss -6.1956 p_acc 0.34375 step 1.0
# Epoch 11/50 loss -3.9195 index_layer_3_loss 2.1238 index_layer_6_loss -6.0434 p_acc 0.375 step 1.0
# Epoch 12/50 loss -3.9977 index_layer_3_loss 2.0086 index_layer_6_loss -6.0063 p_acc 0.3720703125 step 1.0
# Epoch 13/50 loss -4.1547 index_layer_3_loss 1.9606 index_layer_6_loss -6.1153 p_acc 0.3798828125 step 1.0
# Epoch 14/50 loss -4.5289 index_layer_3_loss 1.9144 index_layer_6_loss -6.4432 p_acc 0.3740234375 step 1.0
# Epoch 15/50 loss -4.5208 index_layer_3_loss 1.8721 index_layer_6_loss -6.3929 p_acc 0.3671875 step 1.0
# Epoch 16/50 loss -4.0019 index_layer_3_loss 1.9270 index_layer_6_loss -5.9288 p_acc 0.3642578125 step 1.0
# Epoch 17/50 loss -4.2912 index_layer_3_loss 1.8251 index_layer_6_loss -6.1163 p_acc 0.3935546875 step 1.0
# Epoch 18/50 loss -4.2139 index_layer_3_loss 1.9722 index_layer_6_loss -6.1861 p_acc 0.390625 step 1.0
# Epoch 19/50 loss -4.4820 index_layer_3_loss 1.8535 index_layer_6_loss -6.3355 p_acc 0.3671875 step 1.0
# Epoch 20/50 loss -3.9624 index_layer_3_loss 2.2821 index_layer_6_loss -6.2445 p_acc 0.384765625 step 1.0
# Epoch 21/50 loss -4.0363 index_layer_3_loss 2.1526 index_layer_6_loss -6.1888 p_acc 0.3896484375 step 1.0
# Epoch 22/50 loss -4.3242 index_layer_3_loss 2.1930 index_layer_6_loss -6.5172 p_acc 0.392578125 step 1.0
# Epoch 23/50 loss -4.2900 index_layer_3_loss 1.9421 index_layer_6_loss -6.2321 p_acc 0.3837890625 step 1.0
# Epoch 24/50 loss -4.7041 index_layer_3_loss 1.6654 index_layer_6_loss -6.3695 p_acc 0.3857421875 step 1.0
# Epoch 25/50 loss -4.3774 index_layer_3_loss 1.6886 index_layer_6_loss -6.0660 p_acc 0.3837890625 step 1.0
# Epoch 26/50 loss -4.5870 index_layer_3_loss 1.8531 index_layer_6_loss -6.4400 p_acc 0.39453125 step 1.0
# Epoch 27/50 loss -4.0441 index_layer_3_loss 2.0174 index_layer_6_loss -6.0615 p_acc 0.3935546875 step 1.0
# Epoch 28/50 loss -4.7486 index_layer_3_loss 1.8308 index_layer_6_loss -6.5793 p_acc 0.38671875 step 1.0
# Epoch 29/50 loss -4.7027 index_layer_3_loss 1.7714 index_layer_6_loss -6.4741 p_acc 0.3984375 step 1.0
# Epoch 30/50 loss -4.8828 index_layer_3_loss 1.6414 index_layer_6_loss -6.5242 p_acc 0.3857421875 step 1.0
# Epoch 31/50 loss -4.7016 index_layer_3_loss 1.6781 index_layer_6_loss -6.3798 p_acc 0.40625 step 1.0
# Epoch 32/50 loss -4.6681 index_layer_3_loss 1.8675 index_layer_6_loss -6.5356 p_acc 0.39453125 step 1.0
# Epoch 33/50 loss -2.6402 index_layer_3_loss 1.7608 index_layer_6_loss -4.4010 p_acc 0.419921875 step 1.0
# Epoch 34/50 loss -4.9453 index_layer_3_loss 1.7285 index_layer_6_loss -6.6739 p_acc 0.3740234375 step 1.0
# Epoch 35/50 loss -4.8194 index_layer_3_loss 1.6997 index_layer_6_loss -6.5190 p_acc 0.3896484375 step 1.0
# Epoch 36/50 loss -5.0804 index_layer_3_loss 1.3673 index_layer_6_loss -6.4477 p_acc 0.37890625 step 1.0
# Epoch 37/50 loss -4.9860 index_layer_3_loss 1.7424 index_layer_6_loss -6.7285 p_acc 0.376953125 step 1.0
# Epoch 38/50 loss -4.3811 index_layer_3_loss 1.8357 index_layer_6_loss -6.2168 p_acc 0.4033203125 step 1.0
# Epoch 39/50 loss -4.6741 index_layer_3_loss 1.9217 index_layer_6_loss -6.5959 p_acc 0.39453125 step 1.0
# Epoch 40/50 loss -4.7409 index_layer_3_loss 1.8693 index_layer_6_loss -6.6102 p_acc 0.390625 step 1.0
# Epoch 41/50 loss -4.9389 index_layer_3_loss 1.6020 index_layer_6_loss -6.5409 p_acc 0.384765625 step 1.0
# Epoch 42/50 loss -5.0141 index_layer_3_loss 1.7319 index_layer_6_loss -6.7460 p_acc 0.41015625 step 1.0
# Epoch 43/50 loss -4.8115 index_layer_3_loss 1.8665 index_layer_6_loss -6.6781 p_acc 0.3955078125 step 1.0
# Epoch 44/50 loss -5.4882 index_layer_3_loss 1.2115 index_layer_6_loss -6.6998 p_acc 0.4052734375 step 1.0
# Epoch 45/50 loss -5.1010 index_layer_3_loss 1.5880 index_layer_6_loss -6.6889 p_acc 0.412109375 step 1.0
# Epoch 46/50 loss -5.1169 index_layer_3_loss 1.6658 index_layer_6_loss -6.7827 p_acc 0.3984375 step 1.0
# Epoch 47/50 loss -5.4303 index_layer_3_loss 1.5098 index_layer_6_loss -6.9401 p_acc 0.408203125 step 1.0
# Epoch 48/50 loss -4.9861 index_layer_3_loss 1.4535 index_layer_6_loss -6.4396 p_acc 0.404296875 step 1.0
# Epoch 49/50 loss -4.3572 index_layer_3_loss 1.4326 index_layer_6_loss -5.7899 p_acc 0.3974609375 step 1.0
#
# ITER 7 /10
# Epoch 0/50 loss -4.9175 index_layer_3_loss 1.6047 index_layer_6_loss -6.5222 p_acc 0.384765625 step 1.0
# Epoch 1/50 loss -5.2613 index_layer_3_loss 1.4675 index_layer_6_loss -6.7288 p_acc 0.40234375 step 1.0
# Epoch 2/50 loss -5.3168 index_layer_3_loss 1.5137 index_layer_6_loss -6.8305 p_acc 0.392578125 step 1.0
# Epoch 3/50 loss -4.7690 index_layer_3_loss 1.7149 index_layer_6_loss -6.4839 p_acc 0.4189453125 step 1.0
# Epoch 4/50 loss -4.6075 index_layer_3_loss 1.4046 index_layer_6_loss -6.0121 p_acc 0.4130859375 step 1.0
# Epoch 5/50 loss -5.5667 index_layer_3_loss 1.3105 index_layer_6_loss -6.8772 p_acc 0.390625 step 1.0
# Epoch 6/50 loss -5.3729 index_layer_3_loss 1.2895 index_layer_6_loss -6.6624 p_acc 0.41015625 step 1.0
# Epoch 7/50 loss -5.0738 index_layer_3_loss 1.4970 index_layer_6_loss -6.5708 p_acc 0.419921875 step 1.0
# Epoch 8/50 loss -5.3882 index_layer_3_loss 1.5334 index_layer_6_loss -6.9216 p_acc 0.4169921875 step 1.0
# Epoch 9/50 loss -5.5045 index_layer_3_loss 1.2408 index_layer_6_loss -6.7453 p_acc 0.4072265625 step 1.0
# Epoch 10/50 loss -5.3039 index_layer_3_loss 1.5060 index_layer_6_loss -6.8099 p_acc 0.4013671875 step 1.0
# Epoch 11/50 loss -5.0350 index_layer_3_loss 1.7090 index_layer_6_loss -6.7440 p_acc 0.4091796875 step 1.0
# Epoch 12/50 loss -5.6485 index_layer_3_loss 0.9906 index_layer_6_loss -6.6391 p_acc 0.427734375 step 1.0
# Epoch 13/50 loss -5.2097 index_layer_3_loss 1.5598 index_layer_6_loss -6.7694 p_acc 0.400390625 step 1.0
# Epoch 14/50 loss -5.2413 index_layer_3_loss 1.4273 index_layer_6_loss -6.6686 p_acc 0.4111328125 step 1.0
# Epoch 15/50 loss -5.4846 index_layer_3_loss 1.3943 index_layer_6_loss -6.8789 p_acc 0.3916015625 step 1.0
# Epoch 16/50 loss -5.4367 index_layer_3_loss 1.2562 index_layer_6_loss -6.6929 p_acc 0.4326171875 step 1.0
# Epoch 17/50 loss -5.3389 index_layer_3_loss 1.0920 index_layer_6_loss -6.4309 p_acc 0.4140625 step 1.0
# Epoch 18/50 loss -4.8447 index_layer_3_loss 1.5418 index_layer_6_loss -6.3865 p_acc 0.3974609375 step 1.0
# Epoch 19/50 loss -5.3676 index_layer_3_loss 1.1201 index_layer_6_loss -6.4877 p_acc 0.423828125 step 1.0
# Epoch 20/50 loss -5.3630 index_layer_3_loss 1.4304 index_layer_6_loss -6.7934 p_acc 0.4150390625 step 1.0
# Epoch 21/50 loss -5.5437 index_layer_3_loss 1.2229 index_layer_6_loss -6.7667 p_acc 0.408203125 step 1.0
# Epoch 22/50 loss -4.7207 index_layer_3_loss 1.2531 index_layer_6_loss -5.9739 p_acc 0.3974609375 step 1.0
# Epoch 23/50 loss -5.4267 index_layer_3_loss 1.4017 index_layer_6_loss -6.8284 p_acc 0.3876953125 step 1.0
# Epoch 24/50 loss -5.3501 index_layer_3_loss 1.3696 index_layer_6_loss -6.7197 p_acc 0.4140625 step 1.0
# Epoch 25/50 loss -5.7587 index_layer_3_loss 0.9664 index_layer_6_loss -6.7251 p_acc 0.421875 step 1.0
# Epoch 26/50 loss -5.7122 index_layer_3_loss 0.9734 index_layer_6_loss -6.6856 p_acc 0.416015625 step 1.0
# Epoch 27/50 loss -5.5475 index_layer_3_loss 1.0571 index_layer_6_loss -6.6045 p_acc 0.4326171875 step 1.0
# Epoch 28/50 loss -5.4622 index_layer_3_loss 0.9656 index_layer_6_loss -6.4279 p_acc 0.41015625 step 1.0
# Epoch 29/50 loss -5.7622 index_layer_3_loss 0.9215 index_layer_6_loss -6.6837 p_acc 0.4287109375 step 1.0
# Epoch 30/50 loss -5.8015 index_layer_3_loss 1.2124 index_layer_6_loss -7.0139 p_acc 0.41015625 step 1.0
# Epoch 31/50 loss -5.5664 index_layer_3_loss 1.3725 index_layer_6_loss -6.9389 p_acc 0.40234375 step 1.0
# Epoch 32/50 loss -5.6626 index_layer_3_loss 1.1471 index_layer_6_loss -6.8097 p_acc 0.4140625 step 1.0
# Epoch 33/50 loss -5.8609 index_layer_3_loss 1.1556 index_layer_6_loss -7.0165 p_acc 0.4033203125 step 1.0
# Epoch 34/50 loss -5.8479 index_layer_3_loss 0.9396 index_layer_6_loss -6.7875 p_acc 0.4267578125 step 1.0
# Epoch 35/50 loss -6.0650 index_layer_3_loss 0.9117 index_layer_6_loss -6.9767 p_acc 0.404296875 step 1.0
# Epoch 36/50 loss -5.9762 index_layer_3_loss 0.9547 index_layer_6_loss -6.9310 p_acc 0.4306640625 step 1.0
# Epoch 37/50 loss -5.6157 index_layer_3_loss 0.9817 index_layer_6_loss -6.5973 p_acc 0.38671875 step 1.0
# Epoch 38/50 loss -5.9262 index_layer_3_loss 1.0640 index_layer_6_loss -6.9902 p_acc 0.39453125 step 1.0
# Epoch 39/50 loss -5.8101 index_layer_3_loss 0.9647 index_layer_6_loss -6.7748 p_acc 0.41015625 step 1.0
# Epoch 40/50 loss -5.7650 index_layer_3_loss 1.1390 index_layer_6_loss -6.9039 p_acc 0.419921875 step 1.0
# Epoch 41/50 loss -6.0778 index_layer_3_loss 0.8923 index_layer_6_loss -6.9701 p_acc 0.408203125 step 1.0
# Epoch 42/50 loss -5.8047 index_layer_3_loss 0.9847 index_layer_6_loss -6.7895 p_acc 0.4287109375 step 1.0
# Epoch 43/50 loss -5.1008 index_layer_3_loss 0.7568 index_layer_6_loss -5.8576 p_acc 0.39453125 step 1.0
# Epoch 44/50 loss -5.7503 index_layer_3_loss 1.1281 index_layer_6_loss -6.8784 p_acc 0.4052734375 step 1.0
# Epoch 45/50 loss -5.6808 index_layer_3_loss 1.1475 index_layer_6_loss -6.8283 p_acc 0.3994140625 step 1.0
# Epoch 46/50 loss -5.8516 index_layer_3_loss 1.0492 index_layer_6_loss -6.9008 p_acc 0.435546875 step 1.0
# Epoch 47/50 loss -5.7891 index_layer_3_loss 1.2554 index_layer_6_loss -7.0445 p_acc 0.4501953125 step 1.0
# Epoch 48/50 loss -6.2751 index_layer_3_loss 0.6754 index_layer_6_loss -6.9505 p_acc 0.400390625 step 1.0
# Epoch 49/50 loss -5.8637 index_layer_3_loss 1.0767 index_layer_6_loss -6.9403 p_acc 0.4287109375 step 1.0
#
# ITER 8 /10
# Epoch 0/50 loss -5.5841 index_layer_3_loss 1.1565 index_layer_6_loss -6.7406 p_acc 0.439453125 step 1.0
# Epoch 1/50 loss -5.4121 index_layer_3_loss 1.1444 index_layer_6_loss -6.5565 p_acc 0.423828125 step 1.0
# Epoch 2/50 loss -5.9478 index_layer_3_loss 0.9841 index_layer_6_loss -6.9319 p_acc 0.439453125 step 1.0
# Epoch 3/50 loss -5.2958 index_layer_3_loss 1.1720 index_layer_6_loss -6.4678 p_acc 0.40625 step 1.0
# Epoch 4/50 loss -6.0716 index_layer_3_loss 0.8904 index_layer_6_loss -6.9621 p_acc 0.4072265625 step 1.0
# Epoch 5/50 loss -5.8265 index_layer_3_loss 1.1616 index_layer_6_loss -6.9881 p_acc 0.419921875 step 1.0
# Epoch 6/50 loss -6.1173 index_layer_3_loss 0.8210 index_layer_6_loss -6.9383 p_acc 0.4189453125 step 1.0
# Epoch 7/50 loss -5.5533 index_layer_3_loss 1.2031 index_layer_6_loss -6.7564 p_acc 0.400390625 step 1.0
# Epoch 8/50 loss -5.9527 index_layer_3_loss 1.0597 index_layer_6_loss -7.0124 p_acc 0.42578125 step 1.0
# Epoch 9/50 loss -5.7811 index_layer_3_loss 1.2092 index_layer_6_loss -6.9903 p_acc 0.38671875 step 1.0
# Epoch 10/50 loss -5.7059 index_layer_3_loss 1.2586 index_layer_6_loss -6.9645 p_acc 0.41015625 step 1.0
# Epoch 11/50 loss -5.9807 index_layer_3_loss 1.1401 index_layer_6_loss -7.1208 p_acc 0.4345703125 step 1.0
# Epoch 12/50 loss -5.7271 index_layer_3_loss 1.0595 index_layer_6_loss -6.7866 p_acc 0.408203125 step 1.0
# Epoch 13/50 loss -5.9933 index_layer_3_loss 1.0045 index_layer_6_loss -6.9978 p_acc 0.423828125 step 1.0
# Epoch 14/50 loss -5.2552 index_layer_3_loss 1.1760 index_layer_6_loss -6.4312 p_acc 0.4287109375 step 1.0
# Epoch 15/50 loss -6.3797 index_layer_3_loss 0.6200 index_layer_6_loss -6.9997 p_acc 0.4150390625 step 1.0
# Epoch 16/50 loss -6.0224 index_layer_3_loss 0.9687 index_layer_6_loss -6.9911 p_acc 0.4345703125 step 1.0
# Epoch 17/50 loss -6.2186 index_layer_3_loss 0.8395 index_layer_6_loss -7.0581 p_acc 0.396484375 step 1.0
# Epoch 18/50 loss -3.1558 index_layer_3_loss 0.7925 index_layer_6_loss -3.9483 p_acc 0.4658203125 step 1.0
# Epoch 19/50 loss -5.7359 index_layer_3_loss 0.7471 index_layer_6_loss -6.4830 p_acc 0.412109375 step 1.0
# Epoch 20/50 loss -6.2721 index_layer_3_loss 0.7592 index_layer_6_loss -7.0312 p_acc 0.447265625 step 1.0
# Epoch 21/50 loss -6.0924 index_layer_3_loss 0.9199 index_layer_6_loss -7.0122 p_acc 0.4140625 step 1.0
# Epoch 22/50 loss -6.1648 index_layer_3_loss 0.7765 index_layer_6_loss -6.9413 p_acc 0.43359375 step 1.0
# Epoch 23/50 loss -6.4974 index_layer_3_loss 0.6210 index_layer_6_loss -7.1184 p_acc 0.40234375 step 1.0
# Epoch 24/50 loss -6.3954 index_layer_3_loss 0.6913 index_layer_6_loss -7.0867 p_acc 0.435546875 step 1.0
# Epoch 25/50 loss -5.9519 index_layer_3_loss 1.1593 index_layer_6_loss -7.1112 p_acc 0.4384765625 step 1.0
# Epoch 26/50 loss -6.0966 index_layer_3_loss 1.0181 index_layer_6_loss -7.1146 p_acc 0.4326171875 step 1.0
# Epoch 27/50 loss -6.2134 index_layer_3_loss 0.8325 index_layer_6_loss -7.0459 p_acc 0.44921875 step 1.0
# Epoch 28/50 loss -6.0940 index_layer_3_loss 1.1110 index_layer_6_loss -7.2050 p_acc 0.4375 step 1.0
# Epoch 29/50 loss -6.0870 index_layer_3_loss 1.0570 index_layer_6_loss -7.1440 p_acc 0.44140625 step 1.0
# Epoch 30/50 loss -6.0160 index_layer_3_loss 0.9330 index_layer_6_loss -6.9490 p_acc 0.427734375 step 1.0
# Epoch 31/50 loss -5.9674 index_layer_3_loss 0.9057 index_layer_6_loss -6.8731 p_acc 0.423828125 step 1.0
# Epoch 32/50 loss -6.4102 index_layer_3_loss 0.6426 index_layer_6_loss -7.0528 p_acc 0.42578125 step 1.0
# Epoch 33/50 loss -6.2573 index_layer_3_loss 1.0024 index_layer_6_loss -7.2597 p_acc 0.404296875 step 1.0
# Epoch 34/50 loss -6.3811 index_layer_3_loss 0.6855 index_layer_6_loss -7.0666 p_acc 0.4208984375 step 1.0
# Epoch 35/50 loss -4.2862 index_layer_3_loss 1.1747 index_layer_6_loss -5.4608 p_acc 0.3896484375 step 1.0
# Epoch 36/50 loss -5.9528 index_layer_3_loss 1.1915 index_layer_6_loss -7.1443 p_acc 0.4228515625 step 1.0
# Epoch 37/50 loss -6.1298 index_layer_3_loss 1.0873 index_layer_6_loss -7.2171 p_acc 0.4384765625 step 1.0
# Epoch 38/50 loss -6.2065 index_layer_3_loss 0.7707 index_layer_6_loss -6.9771 p_acc 0.4208984375 step 1.0
# Epoch 39/50 loss -6.6635 index_layer_3_loss 0.5461 index_layer_6_loss -7.2096 p_acc 0.4248046875 step 1.0
# Epoch 40/50 loss -6.2182 index_layer_3_loss 0.5634 index_layer_6_loss -6.7816 p_acc 0.4033203125 step 1.0
# Epoch 41/50 loss -5.7219 index_layer_3_loss 0.7778 index_layer_6_loss -6.4997 p_acc 0.431640625 step 1.0
# Epoch 42/50 loss -6.3783 index_layer_3_loss 0.8060 index_layer_6_loss -7.1843 p_acc 0.4140625 step 1.0
# Epoch 43/50 loss -5.9709 index_layer_3_loss 0.9829 index_layer_6_loss -6.9538 p_acc 0.4111328125 step 1.0
# Epoch 44/50 loss -6.2532 index_layer_3_loss 0.9099 index_layer_6_loss -7.1631 p_acc 0.41015625 step 1.0
# Epoch 45/50 loss -6.1687 index_layer_3_loss 1.0062 index_layer_6_loss -7.1749 p_acc 0.4365234375 step 1.0
# Epoch 46/50 loss -6.4580 index_layer_3_loss 0.7541 index_layer_6_loss -7.2122 p_acc 0.44921875 step 1.0
# Epoch 47/50 loss -6.3065 index_layer_3_loss 0.8392 index_layer_6_loss -7.1456 p_acc 0.4169921875 step 1.0
# Epoch 48/50 loss -6.5499 index_layer_3_loss 0.5641 index_layer_6_loss -7.1140 p_acc 0.4091796875 step 1.0
# Epoch 49/50 loss -6.0393 index_layer_3_loss 0.6803 index_layer_6_loss -6.7196 p_acc 0.43359375 step 1.0
#
# ITER 9 /10
# Epoch 0/50 loss -6.4363 index_layer_3_loss 0.6602 index_layer_6_loss -7.0966 p_acc 0.4072265625 step 1.0
# Epoch 1/50 loss -6.2434 index_layer_3_loss 0.8629 index_layer_6_loss -7.1063 p_acc 0.4306640625 step 1.0
# Epoch 2/50 loss -6.3544 index_layer_3_loss 0.6075 index_layer_6_loss -6.9618 p_acc 0.40625 step 1.0
# Epoch 3/50 loss -4.4857 index_layer_3_loss 0.5337 index_layer_6_loss -5.0194 p_acc 0.3994140625 step 1.0
# Epoch 4/50 loss -6.6461 index_layer_3_loss 0.6329 index_layer_6_loss -7.2790 p_acc 0.421875 step 1.0
# Epoch 5/50 loss -6.4400 index_layer_3_loss 0.7173 index_layer_6_loss -7.1574 p_acc 0.4267578125 step 1.0
# Epoch 6/50 loss -6.5950 index_layer_3_loss 0.4404 index_layer_6_loss -7.0355 p_acc 0.40625 step 1.0
# Epoch 7/50 loss -5.2141 index_layer_3_loss 1.1397 index_layer_6_loss -6.3538 p_acc 0.4150390625 step 1.0
# Epoch 8/50 loss -6.2456 index_layer_3_loss 0.8236 index_layer_6_loss -7.0692 p_acc 0.4208984375 step 1.0
# Epoch 9/50 loss -6.3403 index_layer_3_loss 0.8155 index_layer_6_loss -7.1559 p_acc 0.384765625 step 1.0
# Epoch 10/50 loss -6.2426 index_layer_3_loss 0.9941 index_layer_6_loss -7.2367 p_acc 0.408203125 step 1.0
# Epoch 11/50 loss -6.0188 index_layer_3_loss 0.8986 index_layer_6_loss -6.9174 p_acc 0.412109375 step 1.0
# Epoch 12/50 loss -6.4529 index_layer_3_loss 0.8905 index_layer_6_loss -7.3433 p_acc 0.4267578125 step 1.0
# Epoch 13/50 loss -6.2061 index_layer_3_loss 1.0727 index_layer_6_loss -7.2787 p_acc 0.453125 step 1.0
# Epoch 14/50 loss -6.4347 index_layer_3_loss 0.7412 index_layer_6_loss -7.1759 p_acc 0.435546875 step 1.0
# Epoch 15/50 loss -6.5837 index_layer_3_loss 0.7817 index_layer_6_loss -7.3655 p_acc 0.4150390625 step 1.0
# Epoch 16/50 loss -6.3456 index_layer_3_loss 0.9506 index_layer_6_loss -7.2961 p_acc 0.447265625 step 1.0
# Epoch 17/50 loss -6.9349 index_layer_3_loss 0.3511 index_layer_6_loss -7.2860 p_acc 0.4169921875 step 1.0
# Epoch 18/50 loss -6.6595 index_layer_3_loss 0.5734 index_layer_6_loss -7.2329 p_acc 0.4638671875 step 1.0
# Epoch 19/50 loss -6.5250 index_layer_3_loss 0.8575 index_layer_6_loss -7.3825 p_acc 0.427734375 step 1.0
# Epoch 20/50 loss -6.5270 index_layer_3_loss 0.7905 index_layer_6_loss -7.3174 p_acc 0.40234375 step 1.0
# Epoch 21/50 loss -6.3749 index_layer_3_loss 0.8384 index_layer_6_loss -7.2133 p_acc 0.4150390625 step 1.0
# Epoch 22/50 loss -6.5323 index_layer_3_loss 0.6458 index_layer_6_loss -7.1781 p_acc 0.44140625 step 1.0
# Epoch 23/50 loss -6.4834 index_layer_3_loss 0.7469 index_layer_6_loss -7.2303 p_acc 0.43359375 step 1.0
# Epoch 24/50 loss -3.1327 index_layer_3_loss 0.9014 index_layer_6_loss -4.0341 p_acc 0.439453125 step 1.0
# Epoch 25/50 loss -6.3744 index_layer_3_loss 0.5719 index_layer_6_loss -6.9463 p_acc 0.4189453125 step 1.0
# Epoch 26/50 loss -6.2430 index_layer_3_loss 0.6511 index_layer_6_loss -6.8941 p_acc 0.4228515625 step 1.0
# Epoch 27/50 loss -6.5511 index_layer_3_loss 0.6895 index_layer_6_loss -7.2407 p_acc 0.4306640625 step 1.0
# Epoch 28/50 loss -6.3292 index_layer_3_loss 0.6419 index_layer_6_loss -6.9711 p_acc 0.4091796875 step 1.0
# Epoch 29/50 loss -5.0940 index_layer_3_loss 0.7237 index_layer_6_loss -5.8177 p_acc 0.4140625 step 1.0
# Epoch 30/50 loss -6.3864 index_layer_3_loss 0.6074 index_layer_6_loss -6.9938 p_acc 0.421875 step 1.0
# Epoch 31/50 loss -6.5602 index_layer_3_loss 0.5962 index_layer_6_loss -7.1564 p_acc 0.439453125 step 1.0
# Epoch 32/50 loss -6.6078 index_layer_3_loss 0.6051 index_layer_6_loss -7.2128 p_acc 0.41015625 step 1.0
# Epoch 33/50 loss -6.3090 index_layer_3_loss 0.8972 index_layer_6_loss -7.2063 p_acc 0.447265625 step 1.0
# Epoch 34/50 loss -6.0966 index_layer_3_loss 0.9058 index_layer_6_loss -7.0024 p_acc 0.4130859375 step 1.0
# Epoch 35/50 loss -6.5284 index_layer_3_loss 0.8425 index_layer_6_loss -7.3709 p_acc 0.3974609375 step 1.0
# Epoch 36/50 loss -6.5898 index_layer_3_loss 0.7126 index_layer_6_loss -7.3024 p_acc 0.435546875 step 1.0
# Epoch 37/50 loss -6.5154 index_layer_3_loss 0.9656 index_layer_6_loss -7.4810 p_acc 0.439453125 step 1.0
# Epoch 38/50 loss -6.6248 index_layer_3_loss 0.7443 index_layer_6_loss -7.3691 p_acc 0.4482421875 step 1.0
# Epoch 39/50 loss -6.9180 index_layer_3_loss 0.5603 index_layer_6_loss -7.4783 p_acc 0.4287109375 step 1.0
# Epoch 40/50 loss -6.4226 index_layer_3_loss 0.8845 index_layer_6_loss -7.3071 p_acc 0.4501953125 step 1.0
# Epoch 41/50 loss -5.8922 index_layer_3_loss 0.9688 index_layer_6_loss -6.8610 p_acc 0.4033203125 step 1.0
# Epoch 42/50 loss -6.6217 index_layer_3_loss 0.4036 index_layer_6_loss -7.0253 p_acc 0.423828125 step 1.0
# Epoch 43/50 loss -6.3710 index_layer_3_loss 0.4987 index_layer_6_loss -6.8697 p_acc 0.431640625 step 1.0
# Epoch 44/50 loss -6.4427 index_layer_3_loss 0.4847 index_layer_6_loss -6.9274 p_acc 0.4248046875 step 1.0
# Epoch 45/50 loss -6.3047 index_layer_3_loss 0.8499 index_layer_6_loss -7.1546 p_acc 0.41796875 step 1.0
# Epoch 46/50 loss -6.5226 index_layer_3_loss 0.7291 index_layer_6_loss -7.2517 p_acc 0.42578125 step 1.0
# Epoch 47/50 loss -6.6975 index_layer_3_loss 0.6953 index_layer_6_loss -7.3928 p_acc 0.4443359375 step 1.0
# Epoch 48/50 loss -6.1901 index_layer_3_loss 0.4755 index_layer_6_loss -6.6656 p_acc 0.4248046875 step 1.0
# Epoch 49/50 loss -6.5748 index_layer_3_loss 0.4570 index_layer_6_loss -7.0317 p_acc 0.4140625 step 1.0
#
# ITER 10 /10
# Epoch 0/50 loss -6.1950 index_layer_3_loss 1.0478 index_layer_6_loss -7.2428 p_acc 0.4365234375 step 1.0
# Epoch 1/50 loss -6.4345 index_layer_3_loss 0.9428 index_layer_6_loss -7.3773 p_acc 0.4501953125 step 1.0
# Epoch 2/50 loss -5.8456 index_layer_3_loss 0.5253 index_layer_6_loss -6.3709 p_acc 0.4189453125 step 1.0
# Epoch 3/50 loss -6.6046 index_layer_3_loss 0.8566 index_layer_6_loss -7.4612 p_acc 0.4697265625 step 1.0
# Epoch 4/50 loss -5.9865 index_layer_3_loss 0.6327 index_layer_6_loss -6.6192 p_acc 0.4462890625 step 1.0
# Epoch 5/50 loss -6.2832 index_layer_3_loss 0.7992 index_layer_6_loss -7.0824 p_acc 0.4423828125 step 1.0
# Epoch 6/50 loss -6.6304 index_layer_3_loss 0.7634 index_layer_6_loss -7.3938 p_acc 0.423828125 step 1.0
# Epoch 7/50 loss -6.7081 index_layer_3_loss 0.7412 index_layer_6_loss -7.4493 p_acc 0.4365234375 step 1.0
# Epoch 8/50 loss -6.4751 index_layer_3_loss 0.8481 index_layer_6_loss -7.3232 p_acc 0.4443359375 step 1.0
# Epoch 9/50 loss -6.5149 index_layer_3_loss 0.9040 index_layer_6_loss -7.4188 p_acc 0.4482421875 step 1.0
# Epoch 10/50 loss -6.3111 index_layer_3_loss 0.9293 index_layer_6_loss -7.2404 p_acc 0.4560546875 step 1.0
# Epoch 11/50 loss -6.8795 index_layer_3_loss 0.3936 index_layer_6_loss -7.2731 p_acc 0.4462890625 step 1.0
# Epoch 12/50 loss -6.4849 index_layer_3_loss 0.9305 index_layer_6_loss -7.4154 p_acc 0.4716796875 step 1.0
# Epoch 13/50 loss -6.3119 index_layer_3_loss 0.7920 index_layer_6_loss -7.1039 p_acc 0.44140625 step 1.0
# Epoch 14/50 loss -6.5679 index_layer_3_loss 0.7764 index_layer_6_loss -7.3443 p_acc 0.4521484375 step 1.0
# Epoch 15/50 loss -6.7696 index_layer_3_loss 0.7393 index_layer_6_loss -7.5089 p_acc 0.4404296875 step 1.0
# Epoch 16/50 loss -6.7456 index_layer_3_loss 0.5825 index_layer_6_loss -7.3281 p_acc 0.443359375 step 1.0
# Epoch 17/50 loss -6.9453 index_layer_3_loss 0.4570 index_layer_6_loss -7.4023 p_acc 0.4697265625 step 1.0
# Epoch 18/50 loss -6.7148 index_layer_3_loss 0.5023 index_layer_6_loss -7.2171 p_acc 0.4951171875 step 1.0
# Epoch 19/50 loss -7.2277 index_layer_3_loss 0.2593 index_layer_6_loss -7.4870 p_acc 0.4677734375 step 1.0
# Epoch 20/50 loss -6.8666 index_layer_3_loss 0.4421 index_layer_6_loss -7.3087 p_acc 0.4560546875 step 1.0
# Epoch 21/50 loss -7.0190 index_layer_3_loss 0.3733 index_layer_6_loss -7.3923 p_acc 0.4658203125 step 1.0
# Epoch 22/50 loss -6.7827 index_layer_3_loss 0.4315 index_layer_6_loss -7.2142 p_acc 0.4638671875 step 1.0
# Epoch 23/50 loss -6.9568 index_layer_3_loss 0.3580 index_layer_6_loss -7.3148 p_acc 0.451171875 step 1.0
# Epoch 24/50 loss -6.7495 index_layer_3_loss 0.5681 index_layer_6_loss -7.3176 p_acc 0.466796875 step 1.0
# Epoch 25/50 loss -7.1985 index_layer_3_loss 0.2469 index_layer_6_loss -7.4454 p_acc 0.4521484375 step 1.0
# Epoch 26/50 loss -6.7308 index_layer_3_loss 0.3231 index_layer_6_loss -7.0539 p_acc 0.4775390625 step 1.0
# Epoch 27/50 loss -5.7572 index_layer_3_loss 0.4652 index_layer_6_loss -6.2224 p_acc 0.4716796875 step 1.0
# Epoch 28/50 loss -6.7752 index_layer_3_loss 0.3914 index_layer_6_loss -7.1666 p_acc 0.4765625 step 1.0
# Epoch 29/50 loss -7.0338 index_layer_3_loss 0.4879 index_layer_6_loss -7.5217 p_acc 0.44140625 step 1.0
# Epoch 30/50 loss -6.7094 index_layer_3_loss 0.7223 index_layer_6_loss -7.4316 p_acc 0.455078125 step 1.0
# Epoch 31/50 loss -6.7929 index_layer_3_loss 0.4710 index_layer_6_loss -7.2639 p_acc 0.474609375 step 1.0
# Epoch 32/50 loss -6.9617 index_layer_3_loss 0.4881 index_layer_6_loss -7.4498 p_acc 0.462890625 step 1.0
# Epoch 33/50 loss -6.6187 index_layer_3_loss 0.7998 index_layer_6_loss -7.4185 p_acc 0.458984375 step 1.0
# Epoch 34/50 loss -6.9212 index_layer_3_loss 0.5321 index_layer_6_loss -7.4533 p_acc 0.4423828125 step 1.0
# Epoch 35/50 loss -6.5941 index_layer_3_loss 0.4452 index_layer_6_loss -7.0393 p_acc 0.4482421875 step 1.0
# Epoch 36/50 loss -6.7300 index_layer_3_loss 0.6291 index_layer_6_loss -7.3591 p_acc 0.46875 step 1.0
# Epoch 37/50 loss -6.4521 index_layer_3_loss 0.6915 index_layer_6_loss -7.1436 p_acc 0.46484375 step 1.0
# Epoch 38/50 loss -7.1901 index_layer_3_loss 0.2198 index_layer_6_loss -7.4100 p_acc 0.4755859375 step 1.0
# Epoch 39/50 loss -7.1960 index_layer_3_loss 0.4327 index_layer_6_loss -7.6286 p_acc 0.4384765625 step 1.0
# Epoch 40/50 loss -6.3797 index_layer_3_loss 0.5797 index_layer_6_loss -6.9594 p_acc 0.4609375 step 1.0
# Epoch 41/50 loss -6.9759 index_layer_3_loss 0.4200 index_layer_6_loss -7.3960 p_acc 0.4599609375 step 1.0
# Epoch 42/50 loss -7.0102 index_layer_3_loss 0.3281 index_layer_6_loss -7.3383 p_acc 0.435546875 step 1.0
# Epoch 43/50 loss -5.7249 index_layer_3_loss 0.6615 index_layer_6_loss -6.3865 p_acc 0.4384765625 step 1.0
# Epoch 44/50 loss -6.6961 index_layer_3_loss 0.7504 index_layer_6_loss -7.4465 p_acc 0.4248046875 step 1.0
# Epoch 45/50 loss -7.0450 index_layer_3_loss 0.4375 index_layer_6_loss -7.4824 p_acc 0.4423828125 step 1.0
# Epoch 46/50 loss -7.1137 index_layer_3_loss 0.4914 index_layer_6_loss -7.6051 p_acc 0.4619140625 step 1.0
# Epoch 47/50 loss -7.0698 index_layer_3_loss 0.5204 index_layer_6_loss -7.5902 p_acc 0.47265625 step 1.0
# Epoch 48/50 loss -6.7692 index_layer_3_loss 0.4990 index_layer_6_loss -7.2682 p_acc 0.42578125 step 1.0
# Epoch 49/50 loss -6.4782 index_layer_3_loss 0.7219 index_layer_6_loss -7.2001 p_acc 0.423828125 step 1.0

# %%
plt.plot(np.array(particle_filter.acceptance_rate) * np.array(particle_filter.stepsize))

# %%
fig, axes = plot_convergence(particle_filter.loss_train, particle_filter.acceptance_rate, particle_filter.stepsize, figsize=(5, 5));
axes[0].set_ylim(-5, 5)
axes[1].set_ylim(-10, 0)
#plt.savefig(paper_dir + 'figs/double_well/explore_conv.pdf', bbox_inches='tight')

# %%
xref, Eref = double_well.plot_dimer_energy()

# %%
plot_indices = np.array([0, 1, 2, 5, 7, 10])
fig, axes = plt.subplots(nrows=3, ncols=2, sharex=True, sharey=True, figsize=(6,8))

for i, ax in zip(plot_indices, axes.flatten()):
    h, e = np.histogram(Ds[i], bins=50)
    e = 0.5*(e[:-1] + e[1:])
    ax.plot(e, h, color='darkblue', linewidth=1)
    ax.fill_between(e, np.zeros(len(e)), h, color='blue', alpha=0.7)
    ax.text(-2.5, 3000, str(i*50)+' iter')
    ax.plot(xref, np.exp(-Eref-3.4), color='black', linewidth=3, label='Eq. dist.')
    ax.semilogy()
    #plt.legend(ncol=1, fontsize=16, frameon=False)
    ax.set_ylim(3, 10000)
axes[-1, 0].set_xlabel('$x_1$')
axes[-1, 1].set_xlabel('$x_1$')
axes[0, 0].set_ylabel('sample count')
axes[1, 0].set_ylabel('sample count')
axes[2, 0].set_ylabel('sample count')
#plt.savefig(paper_dir + 'figs/double_well/explore_conv_hist.pdf', bbox_inches='tight')
